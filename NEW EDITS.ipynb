# %%
import pandas as pd

x = pd.read_csv('Desktop/flu/test_set_features.csv')

x.head()
# Out:
#    respondent_id  h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# 0          26707           2.0             2.0                        0.0
# 1          26708           1.0             1.0                        0.0
# 2          26709           2.0             2.0                        0.0
# 3          26710           1.0             1.0                        0.0
# 4          26711           3.0             1.0                        1.0
#
#    behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# 0                   1.0                   0.0                    1.0
# 1                   0.0                   0.0                    0.0
# 2                   0.0                   1.0                    1.0
# 3                   0.0                   0.0                    0.0
# 4                   1.0                   0.0                    1.0
#
#    behavioral_large_gatherings  behavioral_outside_home  \
# ...

# %%
import pandas as pd

x = pd.read_csv('Desktop/flu/Shows.csv')

x.head()
# Out:
#    age  experience  rank nationality   go
# 0   36          10     9          uk   no
# 1   42          12     4         usa   no
# 2   23           4     6           n   no
# 3   52           4     4         usa   no
# 4   43          21     8         usa  yes

# %%
import pandas as pd

x = pd.read_csv('Desktop/flu/DataAnalyst.csv')

x.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
import pandas as pd

x = pd.read_csv('Desktop/flu/Consumer_Complaints.csv', low_memory=False)

x.head()
# Out:
#   Date received                  Product                  Sub-product  \
# 0    07/29/2013            Consumer Loan                 Vehicle loan
# 1    07/29/2013  Bank account or service             Checking account
# 2    07/29/2013  Bank account or service             Checking account
# 3    07/29/2013  Bank account or service             Checking account
# 4    07/29/2013                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub-issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# ...

# %%
import pandas as pd

x = pd.read_csv('Desktop/data/test_set_features.csv')

x.head(6)
# Out:
#    respondent_id  h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# 0          26707           2.0             2.0                        0.0
# 1          26708           1.0             1.0                        0.0
# 2          26709           2.0             2.0                        0.0
# 3          26710           1.0             1.0                        0.0
# 4          26711           3.0             1.0                        1.0
# 5          26712           2.0             2.0                        0.0
#
#    behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# 0                   1.0                   0.0                    1.0
# 1                   0.0                   0.0                    0.0
# 2                   0.0                   1.0                    1.0
# 3                   0.0                   0.0                    0.0
# 4                   1.0                   0.0                    1.0
# ...
