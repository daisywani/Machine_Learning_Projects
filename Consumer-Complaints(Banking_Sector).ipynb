# %% [markdown]
# This is a dataset picked from kaggle. It comprises of Consumer Complaints on Financial products and we’ll see how to classify consumer complaints text into these categories: Debt collection, Consumer Loan, Mortgage, Credit card, Credit reporting, Student loan, Bank account or service, Payday loan, Money transfers, Other financial service, Prepaid card. Also we will try to identify the companies from the dataset

# %%
#reading the consumer_complaints csv file to see the what it contains. I will be using cc in short to mean consumer_complaints
import pandas as pd
import numpy as np

cc = pd.read_csv('C:/Users/daisy/Desktop/data/Consumer_Complaints.csv', low_memory=False)

cc = cc.replace(np.nan,'0', regex=True)

cc.head()
# Out:
#   Date received                  Product                  Sub-product  \
# 0    07/29/2013            Consumer Loan                 Vehicle loan
# 1    07/29/2013  Bank account or service             Checking account
# 2    07/29/2013  Bank account or service             Checking account
# 3    07/29/2013  Bank account or service             Checking account
# 4    07/29/2013                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub-issue  \
# 0                Managing the loan or lease         0
# 1                 Using a debit or ATM card         0
# 2   Account opening, closing, or management         0
# 3                  Deposits and withdrawals         0
# 4  Loan servicing, payments, escrow account         0
#
#   Consumer complaint narrative Company public response  \
# 0                            0                       0
# 1                            0                       0
# ...

# %%
#splitting the dataset into training and testing set
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
#y-axis and will be used to predict x_axis also known as labels
cc_features=cc['Company response to consumer']

#x-axis
cc_labels=cc.drop('Company response to consumer', axis=1)


#splitting the labels and feautures into training and testing sets
cc_labels_train,cc_labels_test,cc_features_train,cc_features_test=train_test_split(cc_labels,cc_features,test_size=0.2)

cc_labels_train.head()
# Out:
#        Date received                  Product  \
# 214172    08/05/2015         Credit reporting
# 632049    10/06/2016  Bank account or service
# 468149    12/09/2014          Debt collection
# 282642    09/06/2013          Debt collection
# 206161    05/28/2015              Credit card
#
#                                   Sub-product  \
# 214172                                      0
# 632049             Other bank product/service
# 468149  Other (i.e. phone, health club, etc.)
# 282642  Other (i.e. phone, health club, etc.)
# 206161                                      0
#
#                                            Issue                   Sub-issue  \
# 214172    Incorrect information on credit report              Account status
# 632049  Making/receiving payments, sending money                           0
# 468149                     Communication tactics  Frequent or repeated calls
# 282642     Cont'd attempts collect debt not owed            Debt is not mine
# ...

# %%
cc_labels_train.shape
# Out:
# (536478, 17)

# %%
cc_labels_test.head()
# Out:
#        Date received                  Product       Sub-product  \
# 396790    02/03/2012              Credit card                 0
# 570862    06/01/2016          Debt collection     I do not know
# 164473    04/25/2014         Credit reporting                 0
# 620896    08/03/2016  Bank account or service  Checking account
# 595284    06/06/2016                 Mortgage      FHA mortgage
#
#                                            Issue         Sub-issue  \
# 396790                          Billing disputes                 0
# 570862     Cont'd attempts collect debt not owed  Debt is not mine
# 164473    Incorrect information on credit report    Account status
# 620896     Problems caused by my funds being low                 0
# 595284  Loan modification,collection,foreclosure                 0
#
#                              Consumer complaint narrative  \
# 396790                                                  0
# ...

# %%
cc_labels_test.shape
# Out:
# (134120, 17)
